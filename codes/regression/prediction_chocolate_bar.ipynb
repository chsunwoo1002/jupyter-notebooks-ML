# %% [markdown]
# # Implementation Logistic Regression to Predict Chocolate Bar by Attribute
#
# ### Author: Sunwoo Choi
#
#
# ### Data Reference
# Repository URL: https://github.com/fivethirtyeight/data/tree/master/candy-power-ranking
#
# Raw data URL: https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv
#
# Thanks to @fivethirtyeight for providing data :)

# %%
# extract data
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv')
df
# Out:
#                 competitorname  chocolate  ...  pricepercent  winpercent
# 0                    100 Grand          1  ...         0.860   66.971725
# 1                 3 Musketeers          1  ...         0.511   67.602936
# 2                     One dime          0  ...         0.116   32.261086
# 3                  One quarter          0  ...         0.511   46.116505
# 4                    Air Heads          0  ...         0.511   52.341465
# ..                         ...        ...  ...           ...         ...
# 80                   Twizzlers          0  ...         0.116   45.466282
# 81                    Warheads          0  ...         0.116   39.011898
# 82        WelchÕs Fruit Snacks          0  ...         0.313   44.375519
# 83  WertherÕs Original Caramel          0  ...         0.267   41.904308
# 84                    Whoppers          1  ...         0.848   49.524113
#
# [85 rows x 13 columns]

# %%
chocolate = np.reshape(df['chocolate'].to_numpy(), (-1))
bar = np.reshape(df['bar'].to_numpy(), (-1))

# logical operator 'and'
# return 1 when cholate bar else return 0
y = np.logical_and(chocolate,bar)

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

testDf = df.drop(['chocolate','competitorname','bar'], axis=1, inplace=False)
headers = testDf.columns.tolist()

maxValue = 0
maxFeature = ''

for feature in headers:
  x = np.reshape(df[feature].to_numpy(), (-1,1))
  X_train, X_test, y_train, y_test = train_test_split(x1, y, test_size=0.30, shuffle=True)
  regr = LogisticRegression()
  regr.fit(X_train,y_train)
  acc = regr.score(X_test,y_test)
  print("The accuracy of feature '%s' to predict %s: %f" %(feature,'chocolate bar', acc))
  if acc > maxValue:
    maxValue = acc
    maxFeature = feature
print("\nThe most effective feature is %s and the accuracy is :%f" %(maxFeature, maxValue))
# Out:
# The accuracy of feature 'fruity' to predict chocolate bar: 0.769231
# The accuracy of feature 'caramel' to predict chocolate bar: 0.769231
# The accuracy of feature 'peanutyalmondy' to predict chocolate bar: 0.769231
# The accuracy of feature 'nougat' to predict chocolate bar: 0.884615
# The accuracy of feature 'crispedricewafer' to predict chocolate bar: 0.692308
# The accuracy of feature 'hard' to predict chocolate bar: 0.730769
# The accuracy of feature 'pluribus' to predict chocolate bar: 0.807692
# The accuracy of feature 'sugarpercent' to predict chocolate bar: 0.769231
# The accuracy of feature 'pricepercent' to predict chocolate bar: 0.730769
# The accuracy of feature 'winpercent' to predict chocolate bar: 0.576923
#
# The most effective feature is nougat and the accuracy is :0.884615

# %% [markdown]
# # Implementation ID3 decision tree from scratch
# # with Mean Squared Error and k-fold validation
#
# ### Author: Sunwoo Choi
#
# ### Data
# Previously cleaned data
#
# ### Data Reference
# Repository URL: https://github.com/kkehoe1985/ga_data_science_final_project/blob/master/combined_data.csv
#
# Raw data URL: https://raw.githubusercontent.com/kkehoe1985/ga_data_science_final_project/master/combined_data.csv

# %%
# Set random seed as 1337
import numpy as np

np.random.seed(1337)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML/cleanDf.csv')

cleanDf = df.drop(['Votes','UnemploymentRate2015','DeepPovAll','AgeTotalPop','MaleRate','FemaleRate','TurnoutRate',
                   'NomalizePopulation','NomalizeMedHHInc2014','NomalizeToalArea','NomalizePopDensity','State','County','NomalizePerCapitaInc','Democrat'], axis=1)
# I delete the  'State' and 'County' eventhough it is categorical variables
# This is because this variable makes the tree to overfit.


genderRate = []
youngOrOld = []
for idx, row in df.iterrows():
  if row['Young'] < row['Old']:
    youngOrOld.append('Old')
  else:
    youngOrOld.append('Young')
  if row['MaleRate'] > row['FemaleRate']:
    genderRate.append('Male')
  else:
    genderRate.append('Female')

cleanDf['GenderRate'] = genderRate
cleanDf['YoungOrOld'] = youngOrOld

cleanDf.drop(['Old','Young','Adult'], axis=1, inplace=True)


headers = cleanDf.columns.tolist()
features = headers.copy()
features.remove('PovertyAllAgesPct2014')
print(features)

cleanDf
# Out:
# ['Education', 'Religion', 'EthnicMale', 'EthnicFemale', 'GenderRate', 'YoungOrOld']
#       PovertyAllAgesPct2014            Education  ... GenderRate YoungOrOld
# 0                     0.162  high school diploma  ...     Female      Young
# 1                     0.099  high school diploma  ...     Female      Young
# 2                     0.100              college  ...     Female      Young
# 3                     0.238  high school diploma  ...     Female      Young
# 4                     0.095              college  ...     Female      Young
# ...                     ...                  ...  ...        ...        ...
# 3140                  0.098              college  ...       Male      Young
# 3141                  0.077   bachelor or higher  ...       Male      Young
# 3142                  0.100  high school diploma  ...       Male      Young
# 3143                  0.126              college  ...       Male      Young
# 3144                  0.132              college  ...       Male      Young
#
# [3145 rows x 7 columns]

# %%
# shuffle & split array into training set and validation set
sampleArr = cleanDf.to_numpy()
np.random.shuffle(sampleArr)

splitIdx = (int)(len(sampleArr)*0.7)

trainSet = sampleArr[:splitIdx]
validSet = sampleArr[splitIdx:]

print(len(trainSet)+len(validSet) == len(sampleArr)) # check any missing row

trainDf = pd.DataFrame(trainSet, columns = headers)
validDf = pd.DataFrame(validSet, columns = headers)
trainDf['PovertyAllAgesPct2014']
# Out:
# True
# 0       0.174
# 1       0.264
# 2       0.135
# 3       0.205
# 4       0.178
#         ...
# 2196    0.195
# 2197     0.25
# 2198    0.169
# 2199    0.196
# 2200    0.099
# Name: PovertyAllAgesPct2014, Length: 2201, dtype: object

# %%
trainDf['PovertyAllAgesPct2014'].std()
# Out:
# 0.06431949313202583

# %%
# Calculate standard deviation of selected matrix
def getSD(labelCol):
  return labelCol.std()

# calculate conditional standard deviation
def getCondSD(cols, colFeature,labelVec):
  sd = 0
  cateFeatures = cols[colFeature].value_counts()
  for cateFeature, count in cateFeatures.items():
    sd += (count/len(cols[colFeature]))*getSD(cols.loc[cols[colFeature] == cateFeature][labelVec])
  return sd

# return attribute which maximize information gain
def selectAttribute(dft, colFeatures,labelVec):
  if colFeatures is []:
    return 0
  wholeEnt = getSD(dft[labelVec])
  IG = {}
  for colFeature in colFeatures:
    IG[colFeature] = wholeEnt - getCondSD(dft[[colFeature,labelVec]], colFeature,labelVec)
  return max(IG, key=IG.get)

# %%
def ID3(trainDf, features, labelVec):
  if trainDf[labelVec].std()/trainDf[labelVec].mean() < 0.1:
    return {('Label',labelVec) : trainDf[labelVec].mean()}
  # no more features to split
  if not features:
    vote = trainDf.value_counts()
    return {('Label',labelVec):trainDf[labelVec].mean()}
  # all labels are same, classifier is done! 

  

  tree = {}
  splitAttribute = selectAttribute(trainDf, features, labelVec)
  attributes = trainDf[splitAttribute].unique()
  for attribute in attributes:
    tree[(splitAttribute,attribute)] = {}
  for node, subTree in tree.items():
    tmpFeature = features.copy()
    tmpFeature.remove(splitAttribute)

    tree[node] = ID3(trainDf.loc[trainDf[splitAttribute]==node[1]], tmpFeature,labelVec)
    
  return tree


labelVec = 'PovertyAllAgesPct2014'

trainedTree = ID3(trainDf, features,labelVec)
trainedTree
# Out:
# {('EthnicFemale',
#   'Black'): {('Education',
#    'bachelor or higher'): {('Religion',
#     'Catholic'): {('Label',
#      'PovertyAllAgesPct2014'): 0.28350000000000003}, ('Religion',
#     'Christian Generic'): {('GenderRate',
#      'Female'): {('YoungOrOld',
#       'Young'): {('EthnicMale',
#        'Black'): {('Label',
#         'PovertyAllAgesPct2014'): 0.17900000000000002}, ('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.19499999999999998}}}}}, ('Education',
#    'college'): {('Religion',
#     'Catholic'): {('EthnicMale',
#      'White'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.07200000000000001}}}},
#    ('Religion',
#     'Christian Generic'): {('EthnicMale',
#      'Black'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label',
#         'PovertyAllAgesPct2014'): 0.2622222222222222}}}, ('EthnicMale',
#      'White'): {('Label', 'PovertyAllAgesPct2014'): 0.2255}}}, ('Education',
#    'high school diploma'): {('Religion',
#     'Catholic'): {('EthnicMale',
#      'Black'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.208}}}, ('EthnicMale',
#      'White'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.161}}}},
#    ('Religion',
#     'Christian Generic'): {('EthnicMale',
#      'Black'): {('YoungOrOld',
#       'Young'): {('GenderRate',
#        'Female'): {('Label',
#         'PovertyAllAgesPct2014'): 0.2979714285714286}, ('GenderRate',
#        'Male'): {('Label',
#         'PovertyAllAgesPct2014'): 0.29488888888888887}}}, ('EthnicMale',
#      'White'): {('GenderRate',
#       'Female'): {('Label', 'PovertyAllAgesPct2014'): 0.26980000000000004},
#      ('GenderRate',
#       'Male'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.329}}}}}, ('Education',
#    'less than high school diploma'): {('Label',
#     'PovertyAllAgesPct2014'): 0.3702857142857143}},
#  ('EthnicFemale',
#   'Native'): {('EthnicMale',
#    'Native'): {('Religion',
#     'Catholic'): {('YoungOrOld',
#      'Young'): {('Education',
#       'college'): {('GenderRate',
#        'Female'): {('Label',
#         'PovertyAllAgesPct2014'): 0.31785697057999995}}, ('Education',
#       'high school diploma'): {('GenderRate',
#        'Female'): {('Label', 'PovertyAllAgesPct2014'): 0.341},
#       ('GenderRate',
#        'Male'): {('Label',
#         'PovertyAllAgesPct2014'): 0.3566666666666667}}}}, ('Religion',
#     'Christian Generic'): {('Label',
#      'PovertyAllAgesPct2014'): 0.3355}}, ('EthnicMale',
#    'White'): {('Label', 'PovertyAllAgesPct2014'): 0.262}},
#  ('EthnicFemale',
#   'White'): {('Education',
#    'bachelor or higher'): {('Religion',
#     'Amish'): {('Label', 'PovertyAllAgesPct2014'): 0.1542848529}, ('Religion',
#     'Catholic'): {('YoungOrOld',
#      'Old'): {('EthnicMale',
#       'White'): {('GenderRate',
#        'Female'): {('Label', 'PovertyAllAgesPct2014'): 0.108}, ('GenderRate',
#        'Male'): {('Label', 'PovertyAllAgesPct2014'): 0.131}}},
#     ('YoungOrOld',
#      'Young'): {('GenderRate',
#       'Female'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.11137735849056603}}, ('GenderRate',
#       'Male'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.1273846153846154}}}}, ('Religion',
#     'Christian Generic'): {('YoungOrOld',
#      'Old'): {('EthnicMale',
#       'White'): {('GenderRate',
#        'Female'): {('Label', 'PovertyAllAgesPct2014'): 0.144}, ('GenderRate',
#        'Male'): {('Label', 'PovertyAllAgesPct2014'): 0.08900000000000001}}},
#     ('YoungOrOld',
#      'Young'): {('EthnicMale',
#       'White'): {('GenderRate',
#        'Female'): {('Label',
#         'PovertyAllAgesPct2014'): 0.1473666666666667}, ('GenderRate',
#        'Male'): {('Label',
#         'PovertyAllAgesPct2014'): 0.16572222222222224}}}}, ('Religion',
#     'Mormon'): {('EthnicMale',
#      'White'): {('GenderRate',
#       'Male'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.116}}}}, ('Religion',
#     'Other'): {('EthnicMale',
#      'White'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.142}}, ('GenderRate',
#       'Male'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.068}}}}}, ('Education',
#    'college'): {('GenderRate',
#     'Female'): {('Religion',
#      'Catholic'): {('YoungOrOld',
#       'Old'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.14875000000000002}}, ('YoungOrOld',
#       'Young'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.15126373626373632}}}, ('Religion',
#      'Christian Generic'): {('YoungOrOld',
#       'Old'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.16599999999999998}},
#      ('YoungOrOld',
#       'Young'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.1555270935960591}}}, ('Religion',
#      'Mormon'): {('Label',
#       'PovertyAllAgesPct2014'): 0.15250000000000002}, ('Religion',
#      'Other'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.14933333333333332}}}},
#    ('GenderRate',
#     'Male'): {('YoungOrOld',
#      'Old'): {('Religion',
#       'Catholic'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.14900000000000002}}, ('Religion',
#       'Christian Generic'): {('EthnicMale',
#        'Black'): {('Label', 'PovertyAllAgesPct2014'): 0.246},
#       ('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.166}}}, ('YoungOrOld',
#      'Young'): {('Religion',
#       'Catholic'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.14437894736842105}},
#      ('Religion',
#       'Christian Generic'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.13271074380165293}},
#      ('Religion',
#       'Mormon'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.13294736842105265}},
#      ('Religion',
#       'Other'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.12990909090909092}}}}}, ('Education',
#    'high school diploma'): {('Religion',
#     'Catholic'): {('GenderRate',
#      'Female'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Old'): {('Label',
#         'PovertyAllAgesPct2014'): 0.15433333333333335}, ('YoungOrOld',
#        'Young'): {('Label',
#         'PovertyAllAgesPct2014'): 0.1452310873699999}}}, ('GenderRate',
#      'Male'): {('YoungOrOld',
#       'Old'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.16587500000000005}},
#      ('YoungOrOld',
#       'Young'): {('EthnicMale',
#        'White'): {('Label', 'PovertyAllAgesPct2014'): 0.15248666666666671}}}},
#    ('Religion',
#     'Christian Generic'): {('GenderRate',
#      'Female'): {('YoungOrOld',
#       'Old'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.16050000000000003}}, ('YoungOrOld',
#       'Young'): {('EthnicMale',
#        'White'): {('Label',
#         'PovertyAllAgesPct2014'): 0.18265156250000023}}}, ('GenderRate',
#      'Male'): {('EthnicMale',
#       'Black'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.261}},
#      ('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Old'): {('Label',
#         'PovertyAllAgesPct2014'): 0.16133333333333338}, ('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.1830484429065744}}}},
#    ('Religion',
#     'Mormon'): {('EthnicMale',
#      'White'): {('GenderRate',
#       'Female'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.134}}, ('GenderRate',
#       'Male'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.172}}}},
#    ('Religion',
#     'Other'): {('EthnicMale',
#      'White'): {('GenderRate',
#       'Male'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.141}}}},
#    ('Religion',
#     'Other Misc'): {('Label',
#      'PovertyAllAgesPct2014'): 0.16949999999999998}}, ('Education',
#    'less than high school diploma'): {('Religion',
#     'Catholic'): {('GenderRate',
#      'Female'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Young'): {('Label',
#         'PovertyAllAgesPct2014'): 0.2871666666666666}}}, ('GenderRate',
#      'Male'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.25507142857142856}}}},
#    ('Religion',
#     'Christian Generic'): {('GenderRate',
#      'Female'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Young'): {('Label', 'PovertyAllAgesPct2014'): 0.2685}}}, ('GenderRate',
#      'Male'): {('EthnicMale',
#       'White'): {('YoungOrOld',
#        'Young'): {('Label',
#         'PovertyAllAgesPct2014'): 0.16333333333333333}}}}}}}

# %%
def predict(row,tree):
  for key, item in tree.items():
    category = key[0]
    cateFeature = key[1]
    if category == 'Label': # when predict function found key 'Label', it returns square of error
      return (row[labelVec]-item)**2
    if row[category] == cateFeature:
      return predict(row, item)
  return 0

def checkAccuracy(checkDf, tree):
  errSum = 0
  for idx, row in checkDf.iterrows():
    errSum += predict(row, tree)
  return errSum/len(checkDf) # sum of error / n : Mean square error


trainedSucRate = checkAccuracy(trainDf, trainedTree)
print("MSE of training set:",trainedSucRate)

validSucRate = checkAccuracy(validDf, trainedTree)
print("MSE of validation set:",validSucRate)
# Out:
# MSE of training set: 0.0027798233838869997
# MSE of validation set: 0.0026717512985704782

# %%
def kFoldValid(cleanDf,headers, k=5):
  # shuffle & split array into training set and validation set
  foldFeatures = headers.copy()
  sampleArr = cleanDf.to_numpy()
  np.random.shuffle(sampleArr)
  validSucRate = []

  splitIdx = (int)(len(sampleArr)*(1/k)) # set split index
  prevIdx = 0 # previous index for slicing
  for count in range(k):
    validSet = sampleArr[prevIdx:splitIdx] # set valid set from previous slicing index to current slicing index
    trainSet = np.append(sampleArr[splitIdx:], sampleArr[:prevIdx], axis=0) # set training set for rest of them
    prevIdx = splitIdx
    splitIdx = splitIdx + (int)(len(sampleArr)*(1/k)) # move to next slicing index
    trainDf = pd.DataFrame(trainSet, columns = headers) # get data from dataframe
    validDf = pd.DataFrame(validSet, columns = headers)
    foldFeatures = headers.copy() # my ID3 function requires header list to check any left features
    foldFeatures.remove('PovertyAllAgesPct2014') # label vector
    labelVec = 'PovertyAllAgesPct2014'
    trainedTree = ID3(trainDf, foldFeatures,labelVec)
    validSucRate.append(checkAccuracy(validDf, trainedTree))
    print("MSE of %d set: %f" %(count+1, validSucRate[count]))

  print("The average MSE of %d-fold cross validation: %f" %(k, sum(validSucRate)/k))

foldHeaders = cleanDf.columns.tolist() 
kFoldValid(cleanDf,foldHeaders)
# Out:
# MSE of 1 set: 0.002644
# MSE of 2 set: 0.002835
# MSE of 3 set: 0.002904
# MSE of 4 set: 0.002673
# MSE of 5 set: 0.003043
# The average MSE of 5-fold cross validation: 0.002820
